# %%
import json
import pandas as pd

df = pd.read_json("matches.jsonl", lines=True)
print(len(df))
df.head()
# Out:
# 1068
#                               id  \
# 0     1930_match_1_france_mexico
# 1  1930_match_2_argentina_france
# 2      1930_match_3_chile_mexico
# 3      1930_match_4_chile_france
# 4  1930_match_5_argentina_mexico
#
#                                                 text  \
# 0  1930 FIFA World Cup — Group Matches, Group 1\n...
# 1  1930 FIFA World Cup — Group Matches, Group 1\n...
# 2  1930 FIFA World Cup — Group Matches, Group 1\n...
# 3  1930 FIFA World Cup — Group Matches, Group 1\n...
# 4  1930 FIFA World Cup — Group Matches, Group 1\n...
#
#                                             metadata
# 0  {'year': 1930, 'tournament': 'FIFA World Cup',...
# 1  {'year': 1930, 'tournament': 'FIFA World Cup',...
# 2  {'year': 1930, 'tournament': 'FIFA World Cup',...
# 3  {'year': 1930, 'tournament': 'FIFA World Cup',...
# 4  {'year': 1930, 'tournament': 'FIFA World Cup',...

# %%
with open("matches.jsonl", "r", encoding="utf-8") as f:
    lines = f.readlines()

first = "".join(lines[:1])
first
# Out:
# '{"id": "1930_match_1_france_mexico", "text": "1930 FIFA World Cup — Group Matches, Group 1\\n\\nFrance vs Mexico\\nDate: 1930-07-13\\nTime: 15:00 UTC-3\\nVenue: Pocitos, Montevideo\\n\\nGoals\\nFrance: - Lucien LAURENT (19\')\\nFrance: - Marcel LANGILLER (40\')\\nFrance: - Andre MASCHINOT (43\')\\nFrance: - Andre MASCHINOT (87\')\\nMexico: - Juan CARRENO (70\')\\n\\nLineups\\nFrance: - Alex THEPOT\\nFrance: - Marcel CAPELLE\\nFrance: - Etienne MATTLER\\nFrance: - Augustin CHANTREL\\nFrance: - Marcel PINEL\\nFrance: - Alex VILLAPLANE (captain)\\nFrance: - Edmond DELFOUR\\nFrance: - Marcel LANGILLER\\nFrance: - Lucien LAURENT\\nFrance: - Ernest LIBERATI\\nFrance: - Andre MASCHINOT\\nFrance: - Oscar BONFIGLIO\\nFrance: - Rafael GARZA (captain)\\nFrance: - Manuel ROSAS\\nFrance: - Efrain AMEZCUA\\nFrance: - Felipe ROSAS\\nFrance: - Alfredo SANCHEZ\\nFrance: - Juan CARRENO\\nFrance: - Hilario LOPEZ\\nFrance: - Dionisio MEJIA\\nFrance: - Jose RUIZ\\nFrance: - Luis PEREZ\\nMexico: - Alex T
# ...

# %%
with open("matches.jsonl", "r", encoding="utf-8") as f:
    lines = f.readlines()

last = "".join(lines[-1:])
last
# Out:
# '{"id": "2026_match_104_spain_argentina", "text": "2026 FIFA World Cup — Final\\n\\nSpain vs Argentina\\nDate: 2026-07-19\\nTime: 15:00 UTC-4\\nVenue: New York/New Jersey Stadium, New Jersey\\n\\nScore\\nFull time: [0, 0]; Extra time: [1, 0]\\n\\nGoals\\nSpain: - Ferran TORRES (106\')\\n\\nLineups\\nSpain: - Unai SIMON\\nSpain: - Pedro PORRO\\nSpain: - Aymeric LAPORTE\\nSpain: - Pau CUBARSI\\nSpain: - Marc CUCURELLA\\nSpain: - Fabian RUIZ\\nSpain: - Alex BAENA\\nSpain: - RODRI (captain)\\nSpain: - Dani OLMO\\nSpain: - Lamine YAMAL\\nSpain: - Mikel OYARZABAL\\nSpain: Eric GARCIA\\nSpain: PEDRI\\nSpain: Nico WILLIAMS\\nSpain: Martin ZUBIMENDI\\nSpain: Mikel MERINO\\nSpain: Ferran TORRES\\nSpain: - Emiliano MARTINEZ\\nSpain: - Nicolas TAGLIAFICO\\nSpain: - Gonzalo MONTIEL\\nSpain: - Lisandro MARTINEZ\\nSpain: - Cristian ROMERO\\nSpain: - Rodrigo DE PAUL\\nSpain: - Nico GONZALEZ\\nSpain: - Alexis MAC ALLISTER\\nSpain: - Enzo FERNANDEZ\\nSpain: - Julian ALVAREZ\\nSpain: - Lionel MESSI (ca
# ...
